# %%
    import os
    print(os.getcwd())
# Out:
# /scratch/ss14729/geant4/apxs/analysis/.ipynb_checkpoints

# %% [markdown]
# # Spectrum Generation
#
# We use the data to generate spectra for the incidence of particles on the detector

# %%
#Include modules
from accelerate import *
from tqdm.notebook import tqdm

# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Include modules
# ----> 2 from accelerate import *
#       3 from tqdm.notebook import tqdm
#       5 get_ipython().run_line_magic('matplotlib', 'widget')
#
# ModuleNotFoundError: No module named 'accelerate'

# %%
# Read the files

# Parameters
run                     = 'Material_Comparison_2023_14_11/PigeoniteBasalt'

# Find the files
foldername  = f'./data/{run}'
filenames   = [os.path.join(foldername,filename) for filename in os.listdir(foldername)]

# Print the number of files found
print(f'Found {len(filenames)} data files in {foldername}')
# Out:
# Found 5000 data files in ./data/Material_Comparison_2023_14_11/FerroanNoriticAnorthosite

# %%
#List of possible materials
FerroanNoriticAnorthosite = {
    'name' : 'Ferroan Noritic Anorthosite',
    'peaks' : {
        'Fe\nKa' : 6.40,
        'Ti\nKa' : 4.51,
        'Si\nKa' : 1.74,
        'Al\nKa' : 1.49,
        'Mg\nKa' : 1.25,
        'O\nKa'  : 0.52,
        'Mn\nKa' : 5.90,
        'Ca\nKa' : 3.69,
        'Na\nKa' : 1.04,
        'K\nKa'  : 3.31,
        'Cr\nKa' : 5.41,
        'Sr\nKa' : 14.16,
    }
}

Basalt = {
    'name' : 'Basalt',
    'peaks' : {
        'Fe\nKa' : 6.40,
        'Fe\nKb' : 7.06,
        'Ti\nKa' : 4.51,
        'Ti\nKb' : 4.93,
        'Si\nKa' : 1.74,
        'Al\nKa' : 1.49,
        'Mg\nKa' : 1.25,
        'O\nKa'  : 0.52,
    }
}

PigeoniteBasalt = {
    'name' : 'Pigeonite Basalt',
    'peaks' : {                
        'O\nKa'  : 0.52,
        'Si\nKa' : 1.74,
        'Ti\nKa' : 4.51,
        'Al\nKa' : 1.49,
        'Fe\nKa' : 6.40,
        'Mn\nKa' : 5.90,
        'Mg\nKa' : 1.25,
        'Ca\nKa' : 3.69,
        'Na\nKa' : 1.04,
        'K\nKa'  : 3.31,
        'P\nKa'  : 2.01,
        'S\nKa'  : 2.30,
        'V\nKa'  : 4.95,
        'Cr\nKa' : 5.41,
        'Sr\nKa' : 14.16,
        'Zr\nKa' : 15.78,

    }
}

ImpactMeltBreccia = {
    'name' : 'Impact Melt Breccia',
    'peaks' : {                
        'O\nKa'  : 0.52,
        'Si\nKa' : 1.74,
        'Ti\nKa' : 4.51,
        'Al\nKa' : 1.49,
        'Fe\nKa' : 6.40,
        'Mn\nKa' : 5.90,
        'Mg\nKa' : 1.25,
        'Ca\nKa' : 3.69,
        'Na\nKa' : 1.04,
        'K\nKa'  : 3.31,
        'P\nKa'  : 2.01,
        'Cr\nKa' : 5.41,
        'Sr\nKa' : 14.16,
        'Ni\nKa' : 7.48,
        'Ba\nKa' : 32.19,


    }
}

# %%
RUN_STRUCTURE = {
    'run0' : 'Cm244',
    'run1' : 'Fe55',
    'run2' : 'Cd109',
    'run3' : 'Co60',
    'run4' : 'Am241'
}

MATERIAL = FerroanNoriticAnorthosite

STD                 = 0.04
particleEnergyList  = {}
PARTICLES           = ['gamma']
EFFICIENCY          = pd.read_csv('./data/SDD_Efficiency/C1.csv', names=['Energy','Efficiency'])

# For all the simulation runs
pbar = tqdm(RUN_STRUCTURE,desc=list(RUN_STRUCTURE.values())[0])
for i,run in enumerate(pbar):
    # Collect their output files
    files = loadFiles([filename for filename in filenames if run in filename])
    print(files)
    

    # Extract the energy for each particle
    particleEnergyList[run] = getParticleEnergiesSmeared(files,
        smearfunc   = smear_gaussian,
        size        = STD,
        groupBy     = 'TrackID',
        columnName  = 'InitialEnergy'
        )
    
    particles = None
    try:
        particles = pd.concat([particleEnergyList[run][p] for p in PARTICLES])
    except:
        pass
    
    # Plot the spectrum
    if particles is not None : plotParticleHistogram(particles,
        source          = RUN_STRUCTURE[run],
        PARTICLE        = ' and '.join(PARTICLES),
        MATERIAL        = MATERIAL,
        SHOW_MATERIAL   = True,
        LIMS            = (0,8),
        MAX_PEAKS       = 0,
        NBINS           = 1000,
        SAVE            = True,
        yscale          = 'log',
        efficiency      = EFFICIENCY)

    # Change the description of the progress bar to show the material processed
    try:
        pbar.set_description(list(RUN_STRUCTURE.values())[i+1])
    except:
        pass
# Out:
# Cm244:   0%|          | 0/5 [00:00<?, ?it/s]
# loadFile:   0%|          | 0/1000 [00:00<?, ?it/s]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# getEnergy:   0%|          | 0/1000 [00:00<?, ?it/s]
# smearEnergy:   0%|          | 0/1000 [00:00<?, ?it/s]
# loadFile:   0%|          | 0/1000 [00:00<?, ?it/s]
# [   EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0   117427      107         -1    gamma        3.98099                0
# 1   329102      126         -1    gamma        3.65596                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    4.96481        7.8  -2.371160   0.137297  detectLogical_PV
# 1    7.99887        7.8   0.173605   0.812217  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    23720      109         -1    gamma        3.65980                0
# 1    89895      108         -1    gamma        3.65980                0
# 2   108577      107         -1    gamma        3.65596                0
# 3   143654      107         -1    gamma        3.65596                0
# 4   209898      120         -1    gamma        3.65980                0
# 5   310877      127         -1    gamma        3.65980                0
# 6   465949      109         -1    gamma        3.65980                0
# 7   493376      107         -1    gamma        3.65596                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    6.62087    7.80000   0.883182   2.081370  detectLogical_PV
# 1    8.62876    7.80000   1.130420   0.821591  detectLogical_PV
# 2    8.34655    7.80000  -3.031500   0.752712  detectLogical_PV
# 3    7.07886    7.80000   2.495470   6.972740  detectLogical_PV
# 4    7.00542    7.74222  -3.985630   0.909097  detectLogical_PV
# 5    9.33428    7.80000   2.259090   0.254863  detectLogical_PV
# 6    4.90218    7.80000  -1.128000   3.653250  detectLogical_PV
# 7    6.11920    7.80000  -0.111778   1.241920  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical
# 5  targetPhysical
# 6  targetPhysical
# 7  targetPhysical  ,     EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0     12505      120         -1    gamma        3.65980                0
# 1     30927      109         -1    gamma        3.65980                0
# 2     52181      107         -1    gamma        3.65980                0
# 3     82253      109         -1    gamma        3.65596                0
# 4    117293      103         -1    gamma        5.68047                0
# 5    122505      126         -1    gamma        3.65596                0
# 6    178230      108         -1    gamma        3.65596                0
# 7    181083      110         -1    gamma        3.65980                0
# 8    193809      124         -1    gamma        3.65980                0
# 9    359678      118         -1    gamma        3.98140                0
# 10   397898      119         -1    gamma        3.98099                0
# 11   472932      109         -1    gamma        3.65980                0
#
#     XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0     7.90965    7.77093  -3.801970   1.228070  detectLogical_PV
# 1     9.04082    7.80000   0.217310   1.393080  detectLogical_PV
# 2     6.74286    7.80000   0.271459   1.035250  detectLogical_PV
# 3     4.80610    7.80000  -0.340513   1.327620  detectLogical_PV
# 4     8.99397    7.80000   1.242600   7.871440  detectLogical_PV
# 5     5.34314    7.80000   1.447910   6.110830  detectLogical_PV
# 6    10.42320    7.80000  -0.618843   9.950010  detectLogical_PV
# 7     8.12721    7.80000  -0.303185   0.905643  detectLogical_PV
# 8     4.01787    7.80000   1.584450   4.750950  detectLogical_PV
# 9     7.26595    7.80000  -2.108470   0.358107  detectLogical_PV
# 10    7.97523    7.80000  -2.622240   0.432740  detectLogical_PV
# 11    5.03568    7.80000   3.557070   0.452043  detectLogical_PV
#
#       ParentVolume
# 0   targetPhysical
# 1   targetPhysical
# 2   targetPhysical
# 3   targetPhysical
# 4   sourcePhysical
# 5   targetPhysical
# 6   targetPhysical
# 7   targetPhysical
# 8   targetPhysical
# 9   targetPhysical
# 10  targetPhysical
# 11  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    91832      121         -1    gamma        3.65980                0
# 1    99913      122         -1    gamma        3.65596                0
# 2   344834      123         -1    gamma        3.65980                0
# 3   383296      109         -1    gamma        3.65980                0
# 4   425087      125         -1    gamma        5.75805                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    8.68120        7.8   1.751860   0.059025  detectLogical_PV
# 1    9.11611        7.8   0.748746   3.410200  detectLogical_PV
# 2    8.08760        7.8  -1.149930   4.717670  detectLogical_PV
# 3    6.48006        7.8   2.451840   3.380330  detectLogical_PV
# 4    5.46377        7.8  -1.347790   3.568760  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  sourcePhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    23251      120         -1    gamma        3.65980                0
# 1    47424      109         -1    gamma        3.65596                0
# 2   144095      121         -1    gamma        3.65596                0
# 3   163584      128         -1    gamma        3.65980                0
# 4   248767      107         -1    gamma        3.65596                0
# 5   447534      107         -1    gamma        3.65980                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    9.99377        7.8  -1.278640    6.45818  detectLogical_PV
# 1    5.12832        7.8  -0.009814    5.67017  detectLogical_PV
# 2    4.44755        7.8  -0.379852    5.52652  detectLogical_PV
# 3   10.63460        7.8   0.164945    5.54489  detectLogical_PV
# 4    7.36784        7.8   1.587700    9.35705  detectLogical_PV
# 5    8.65178        7.8   1.151080    1.19259  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical
# 5  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    46359      110         -1    gamma        3.65596                0
# 1   167417      126         -1    gamma        3.65596                0
# 2   169002      123         -1    gamma        3.65980                0
# 3   358738      109         -1    gamma        3.65980                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    4.54426        7.8   1.023250   0.939373  detectLogical_PV
# 1    5.58015        7.8  -2.585390  13.849900  detectLogical_PV
# 2    3.46874        7.8  -0.379146   0.059465  detectLogical_PV
# 3    6.27208        7.8  -2.603600   5.916150  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical  ,     EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0      1719      116         -1    gamma        3.98140                0
# 1     17493      124         -1    gamma        1.46917                0
# 2     23981      128         -1    gamma        1.71983                0
# 3     43394      103         -1    gamma        5.85870                0
# 4     55521      124         -1    gamma        1.72052                0
# 5    179915      107         -1    gamma        3.65980                0
# 6    185051      110         -1    gamma        3.65980                0
# 7    217079      121         -1    gamma        3.65980                0
# 8    217081      107         -1    gamma        3.65980                0
# 9    372782      120         -1    gamma        3.65980                0
# 10   397459      121         -1    gamma        3.98140                0
# 11   412584      113         -1    gamma        5.85867                0
# 12   413163      116         -1    gamma        3.98140                0
#
#     XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0     8.93074    7.54344  -3.297570   1.736100  detectLogical_PV
# 1     5.60038    7.80000  -0.457746   1.283530  detectLogical_PV
# 2     8.24832    7.80000   1.577440   2.915810  detectLogical_PV
# 3     8.25120    7.80000   0.462308   1.382810  detectLogical_PV
# 4     6.01428    7.80000   3.415290   6.619320  detectLogical_PV
# 5     5.51135    7.80000   1.974250   4.824200  detectLogical_PV
# 6     8.05252    7.80000   1.799240   1.168390  detectLogical_PV
# 7     5.04360    7.80000  -3.135880   0.008568  detectLogical_PV
# 8     3.09216    7.48091  -1.795240   4.064890  detectLogical_PV
# 9     5.38423    7.80000  -0.485269   1.277090  detectLogical_PV
# 10    8.43045    7.80000   2.324560   0.566116  detectLogical_PV
# 11    9.83365    7.80000  -1.375940   1.275660  detectLogical_PV
# 12   10.25580    7.80000  -0.161081   5.655240  detectLogical_PV
#
#       ParentVolume
# 0   targetPhysical
# 1   targetPhysical
# 2              NaN
# 3   sourcePhysical
# 4   targetPhysical
# 5   targetPhysical
# 6   targetPhysical
# 7   targetPhysical
# 8   targetPhysical
# 9   targetPhysical
# 10  targetPhysical
# 11  sourcePhysical
# 12  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0     7970      110         -1    gamma        3.65596                0
# 1    25513      109         -1    gamma        3.65980                0
# 2   173887      117         -1    gamma        5.85868                0
# 3   214100      109         -1    gamma        3.65980                0
# 4   393457      105         -1    gamma        5.85867                0
# 5   462074      120         -1    gamma        3.65596                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    6.87653    7.80000   1.908820    4.10964  detectLogical_PV
# 1   10.02330    7.51756   2.175580   10.28890  detectLogical_PV
# 2    9.42601    7.80000   1.454330    9.81198  detectLogical_PV
# 3    6.77651    7.80000  -0.145604    3.73354  detectLogical_PV
# 4    5.00619    7.80000  -0.661035    3.23427  detectLogical_PV
# 5    4.68961    7.80000   1.297520    8.81300  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  sourcePhysical
# 3  targetPhysical
# 4  sourcePhysical
# 5  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    93913      128         -1    gamma        3.65980                0
# 1    98140      108         -1    gamma        3.65980                0
# 2   100436      124         -1    gamma        3.65596                0
# 3   156291      109         -1    gamma        3.65980                0
# 4   162091      115         -1    gamma        3.65980                0
# 5   289287      122         -1    gamma        3.65980                0
# 6   339211      109         -1    gamma        3.65596                0
# 7   362029      108         -1    gamma        3.65980                0
# 8   416174      132         -1    gamma        3.65980                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    8.19352        7.8   1.378630   0.393619  detectLogical_PV
# 1    7.31600        7.8   0.534150   5.393800  detectLogical_PV
# 2    4.66458        7.8  -1.110860   0.519569  detectLogical_PV
# 3    8.69747        7.8   2.870280   0.443293  detectLogical_PV
# 4    6.28003        7.8  -0.874842   1.739060  detectLogical_PV
# 5    8.39532        7.8   0.988110   0.873030  detectLogical_PV
# 6    7.24583        7.8  -3.495760   0.805565  detectLogical_PV
# 7    9.00635        7.8   1.301950   0.194590  detectLogical_PV
# 8   10.25340        7.8   1.227300   1.997930  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical
# 5  targetPhysical
# 6  targetPhysical
# 7  targetPhysical
# 8  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0
detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  sourcePhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0   151252      108         -1    gamma        3.65596     0.000000e+00
# 1   219238      110         -1       e-        1.95114     1.674700e-21
# 2   299556      124         -1    gamma        3.65596     0.000000e+00
# 3   322886      109         -1    gamma        3.65596     0.000000e+00
# 4   350202      109         -1    gamma        3.65980     0.000000e+00
# 5   372298      115         -1    gamma        3.65980     0.000000e+00
# 6   376575      107         -1    gamma        3.98099     0.000000e+00
# 7   441818      114         -1    gamma        5.85869     0.000000e+00
# 8   462163      109         -1    gamma        3.65980     0.000000e+00
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    9.94298    7.53991  -2.294730   0.377759  detectLogical_PV
# 1    3.92921    7.80000   2.728280   0.556419  detectLogical_PV
# 2    7.04476    7.80000   0.207202   0.932292  detectLogical_PV
# 3    8.15026    7.80000  -2.665670   1.081160  detectLogical_PV
# 4    5.34773    7.80000  -0.361186   8.448450  detectLogical_PV
# 5    8.85137    7.80000  -2.379870   1.839000  detectLogical_PV
# 6    7.13025    7.80000   3.450400   0.603826  detectLogical_PV
# 7    9.25418    7.80000   2.505370   4.898500  detectLogical_PV
# 8    5.55107    7.80000   0.411739   4.594560  detectLogical_PV
#
#         ParentVolume
# 0     targetPhysical
# 1  sddCaseLogical_PV
# 2     targetPhysical
# 3     targetPhysical
# 4     targetPhysical
# 5     targetPhysical
# 6     targetPhysical
# 7     sourcePhysical
# 8     targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    36208      123         -1    gamma        3.65980                0
# 1   102392      122         -1    gamma        3.65980                0
# 2   121572      109         -1    gamma        3.65596                0
# 3   329357      124         -1    gamma        3.65596                0
# 4   407554      129         -1    gamma        3.65596                0
# 5   454428      116         -1    gamma        5.84791                0
# 6   473799      106         -1    gamma        5.69715                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    9.79541    7.49802  -2.492180   4.695170  detectLogical_PV
# 1   10.05610    7.71645  -2.124100   3.860280  detectLogical_PV
# 2    7.90991    7.45629  -3.801890   4.750930  detectLogical_PV
# 3    5.45975    7.80000  -3.229540   0.604373  detectLogical_PV
# 4    4.44420    7.80000   1.046560   7.715550  detectLogical_PV
# 5    6.70877    7.80000  -1.814910   0.688299  detectLogical_PV
# 6    7.14351    7.80000   0.623627   2.625290  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical
# 5  sourcePhysical
# 6  sourcePhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    47275      120         -1    gamma        3.65980                0
# 1    82762      122         -1    gamma        3.65980                0
# 2   240636      124         -1    gamma        3.65596                0
# 3   353923      123         -1    gamma        3.65980                0
# 4   372386      127         -1    gamma        3.65980                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    7.27149        7.8  -0.216939    4.34204  detectLogical_PV
# 1    6.81324        7.8  -0.679562    1.63709  detectLogical_PV
# 2   10.13460        7.8   0.410948    2.56066  detectLogical_PV
# 3    4.34433        7.8   0.239875    1.73032  detectLogical_PV
# 4    8.00371        7.8   0.926494    1.16446  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    85935      103         -1    gamma        5.71728                0
# 1   218774      123         -1    gamma        3.65596                0
# 2   467787      115         -1    gamma        3.65980                0
# 3   490672      104         -1    gamma        5.75584                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0
Position  YPosition  ZPosition  LocalTime            Volume  \
# 0     6.26480    7.80000  -0.710068   2.929270  detectLogical_PV
# 1     3.68129    7.80000   2.616100   0.316976  detectLogical_PV
# 2     5.19587    7.80000   0.542084   1.560120  detectLogical_PV
# 3     5.78513    7.80000   2.973400   2.558800  detectLogical_PV
# 4     9.94769    7.47169   2.287990   4.193000  detectLogical_PV
# 5     5.26176    7.80000  -0.864082   0.203177  detectLogical_PV
# 6     5.04664    7.80000   0.800584   8.823230  detectLogical_PV
# 7     8.47174    7.80000  -3.243680   2.527250  detectLogical_PV
# 8     5.68820    7.80000  -0.526658   0.716496  detectLogical_PV
# 9     6.67706    7.80000  -2.305620   5.007220  detectLogical_PV
# 10    8.32347    7.80000  -2.133420   2.620880  detectLogical_PV
#
#       ParentVolume
# 0   sourcePhysical
# 1   targetPhysical
# 2   targetPhysical
# 3   targetPhysical
# 4   targetPhysical
# 5   sourcePhysical
# 6   sourcePhysical
# 7   targetPhysical
# 8   targetPhysical
# 9   sourcePhysical
# 10  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0   130159      121         -1    gamma        3.65980                0
# 1   201475      109         -1    gamma        3.65980                0
# 2   331878      118         -1    gamma        3.65980                0
# 3   372047      109         -1    gamma        3.65980                0
# 4   443358      121         -1    gamma        5.85867                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    8.52910    7.80000  -0.530893    1.07614  detectLogical_PV
# 1    9.31035    7.80000   2.935930    5.36623  detectLogical_PV
# 2    7.12513    7.80000  -0.313659    6.24946  detectLogical_PV
# 3    3.83241    7.58049  -2.822590    4.36560  detectLogical_PV
# 4    8.61968    7.80000  -3.180950    9.64143  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  sourcePhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    24907      124         -1    gamma       3.655960     0.000000e+00
# 1   120594      119         -1    gamma       3.655960     0.000000e+00
# 2   169119      103         -1    gamma       6.346770     0.000000e+00
# 3   192509      118         -1       e-       0.619459     4.507020e-21
# 4   204377      109         -1    gamma       3.659800     0.000000e+00
# 5   231780      120         -1    gamma       3.659800     0.000000e+00
# 6   253995      125         -1    gamma       3.659800     0.000000e+00
# 7   434608      107         -1    gamma       3.659800     0.000000e+00
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    4.99430    7.80000  -2.576840   3.955410  detectLogical_PV
# 1    6.89304    7.80000   0.374755   2.728140  detectLogical_PV
# 2   10.32150    7.80000   0.596389   0.841734  detectLogical_PV
# 3    6.19637    7.80000   0.036134   8.230700  detectLogical_PV
# 4    9.99267    7.45548   2.222090   5.049650  detectLogical_PV
# 5    4.35526    7.80000  -0.609029   0.666470  detectLogical_PV
# 6    5.45055    7.80000  -2.149860   0.888502  detectLogical_PV
# 7    5.85216    7.80000   1.546400   4.214790  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  sourcePhysical
# 3  sourcePhysical
# 4  targetPhysical
# 5  targetPhysical
# 6  targetPhysical
# 7  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0   124255      108         -1    gamma        3.65980                0
# 1   174011      119         -1    gamma        3.65596                0
# 2   185257      113         -1    gamma        1.82195                0
# 3   196129      109         -1    gamma        3.65980                0
# 4   220414      109         -1    gamma        3.65596                0
# 5   246092      116         -1    gamma        3.65980                0
# 6   264179      117         -1    gamma        3.65980                0
# 7   322641      107         -1    gamma        3.65596                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    3.35486    7.80000  -1.482110    8.06528  detectLogical_PV
# 1   10.21260    7.45927   1.851040    2.60078  detectLogical_PV
# 2    5.06841    7.80000  -2.101100    6.79675  detectLogical_PV
# 3    8.93809    7.80000  -3.170540    3.04375  detectLogical_PV
# 4   10.66660    7.75775  -0.023039    5.12970  detectLogical_PV
# 5    3.94652    7.80000  -2.190740    0.19670  detectLogical_PV
# 6   10.39020    7.80000  -0.565569    2.77131  detectLogical_PV
# 7    5.50552    7.80000  -3.360870    5.03818  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2             NaN
# 3  targetPhysical
# 4  targetPhysical
# 5  targetPhysical
# 6  targetPhysical
# 7  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0   326068      109         -1    gamma        3.65596                0
# 1   332590      108         -1    gamma        3.65596                0
# 2   487697      109         -1    gamma        3.65980                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    9.81066        7.8   0.296371   4.053970  detectLogical_PV
# 1    8.00847        7.8   3.242920   0.040163  detectLogical_PV
# 2    8.30366        7.8  -2.936210   3.974310  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    31572      110         -1    gamma        3.65596                0
# 1   459178      109         -1    gamma        3.65980                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    4.41249        7.8  -0.287375    6.20268  detectLogical_PV
# 1    5.28556        7.8   3.458730    5.61465  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical  ,     EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    107363      109         -1    gamma        1.72052                0
# 1    110810      120         -1    gamma        3.65980                0
# 2    130607      109         -1    gamma        3.65980                0
# 3    210371      119         -1    gamma        3.65980                0
# 4    236850      110         -1    gamma        3.65596                0
# 5    255332      119         -1    gamma        5.85870                0
# 6    282782      118         -1    gamma        3.65596                0
# 7    298031      108         -1    gamma        3.65980                0
# 8    319982      105         -1    gamma        5.85867                0
# 9    433521      117         -1    gamma        3.65596                0
# 10   446310      110         -1    gamma        3.65980                0
#
#     XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0     5.44167    7.80000  -0.789803   1.798790  detectLogical_PV
# 1     6.47910    7.80000   2.853760  15.961400  detectLogical_PV
# 2     7.68939    7.80000  -1.663440   3.015900  detectLogical_PV
# 3     7.79141    7.80000  -1.617090   0.319288  detectLogical_PV
# 4     4.12240    7.72544  -3.086530   0.034944  detectLogical_PV
# 5     6.99729    7.80000  -2.315580   1.890840  detectLogical_PV
# 6     6.25765    7.80000  -3.804410   1.033770  detectLogical_PV
# 7     5.76859    7.80000   3.389710   4.070910  detectLogical_PV
# 8     6.34638    7.80000  -1.277590  22.708400  detectLogical_PV
# 9     7.62642    7.80000  -3.551630   7.172090  detectLogical_PV
# 10    8.23783    7.80000   0.429526   0.948180  detectLogical_PV
#
#       ParentVolume
# 0   targetPhysical
# 1   targetPhysical
# 2   targetPhysical
# 3   targetPhysical
# 4   targetPhysical
# 5   sourcePhysical
# 6   targetPhysical
# 7   targetPhysical
# 8   sourcePhysical
# 9   targetPhysical
# 10  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    92216      108         -1    gamma        3.98140                0
# 1   328142      122         -1    gamma        3.98099                0
# 2   481811      109         -1    gamma        3.98099                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0   10.13920        7.8  -1.405900   8.988550  detectLogical_PV
# 1    9.17966        7.8   1.609090   3.378320  detectLogical_PV
# 2    5.41579        7.8  -0.231643   0.538795  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    27152      105         -1    gamma        5.84792                0
# 1    74187      119         -1    gamma        3.65596                0
# 2   191474      107         -1    gamma        3.65980                0
# 3   250473      116         -1    gamma        3.98099                0
# 4   267656      107         -1    gamma        3.65596                0
# 5   311969      119         -1    gamma        3.65980                0
# 6   332676      109         -1    gamma        1.71983                0
# 7   383396      122         -1    gamma        3.65596                0
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    9.16101        7.8   2.301740   0.717057  detectLogical_PV
# 1    7.37615        7.8   2.594220   4.594580  detectLogical_PV
# 2    7.77018        7.8  -0.391186   0.435347  detectLogical_PV
# 3    5.91077        7.8   1.690980   0.225557  detectLogical_PV
# 4    6.41837        7.8  -3.109900   0.534920  detectLogical_PV
# 5    5.03340        7.8   1.859010   2.650840  detectLogical_PV
# 6    8.48693        7.8  -1.101060   0.085099  detectLogical_PV
# 7    5.29803        7.8   1.661540   9.494450  detectLogical_PV
#
#      ParentVolume
# 0  sourcePhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical
# 5  targetPhysical
# 6  targetPhysical
# 7  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    72986      120         -1    gamma       3.659800     0.000000e+00
# 1   173314      109         -1    gamma       1.719830     0.000000e+00
# 2   182247      109         -1    gamma       3.655960     0.000000e+00
# 3   186446      125         -1    gamma       3.655960     0.000000e+00
# 4   200199      128         -1    gamma       1.719830     0.000000e+00
# 5   220729      119         -1       e-       0.502144     5.565210e-21
# 6   352808      108         -1    gamma       3.659800     0.000000e+00
# 7   367883      109         -1    gamma       3.659800     0.000000e+00
# 8   458373      108         -1    gamma       3.659800     0.000000e+00
# 9   468748      129         -1    gamma       3.659800     0.000000e+00
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    5.13449    7.80000  -0.971823   9.080300  detectLogical_PV
# 1    5.84579    7.80000  -0.412666   0.006077  detectLogical_PV
# 2    7.70255    7.80000   1.061510   2.402050  detectLogical_PV
# 3    4.69002    7.80000  -2.627510   0.857892  detectLogical_PV
# 4    7.98900    7.80000   0.301866   0.709523  detectLogical_PV
# 5    5.34870    7.80000   0.399789   2.625100  detectLogical_PV
# 6    9.64118    7.80000   1.842280   0.857398  detectLogical_PV
# 7    5.71439    7.80000   0.219766   1.658510  detectLogical_PV
# 8    4.88268    7.79742  -3.580140   2.630780  detectLogical_PV
# 9    9.34554    7.41682  -2.970460   2.223360  detectLogical_PV
#
#      ParentVolume
# 0  targetPhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical
# 5  sourcePhysical
# 6  targetPhysical
# 7  targetPhysical
# 8  targetPhysical
# 9  targetPhysical  ,    EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0    73163      111         -1       e-       0.225047     1.210960e-20
# 1   134707      114         -1    gamma       3.655960     0.000000e+00
# 2   160372      107         -1    gamma       3.655960     0.000000e+00
# 3   172712      124         -1    gamma       3.655960     0.000000e+00
# 4   206967      107         -1    gamma       3.659800     0.000000e+00
# 5   258539      109         -1    gamma       1.719830     0.000000e+00
# 6   375453      107         -1    gamma       1.719830     0.000000e+00
# 7   421551      109         -1    gamma       3.659800     0.000000e+00
# 8   490498      107         -1    gamma       3.655960     0.000000e+00
#
#    XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0    2.82194    7.68186  -1.103680   1.311100  detectLogical_PV
# 1    3.78938    7.80000   1.492360   4.279100  detectLogical_PV
# 2    8.54056    7.80000   1.842010  13.384200  detectLogical_PV
# 3    6.96834    7.80000   1.857680  11.841000  detectLogical_PV
# 4    7.06743    7.80000   0.335994   0.109825  detectLogical_PV
# 5    2.66707    7.34616  -0.056583   1.843120  detectLogical_PV
# 6    6.65682    7.80000  -1.261950   6.794980  detectLogical_PV
# 7    5.03088    7.80000   1.464420   2.036750  detectLogical_PV
# 8    5.91135    7.80000   2.754950   3.634850  detectLogical_PV
#
#      ParentVolume
# 0  sourcePhysical
# 1  targetPhysical
# 2  targetPhysical
# 3  targetPhysical
# 4  targetPhysical
# 5  targetPhysical
# 6  targetPhysical
# 7  targetPhysical
# 8  targetPhysical  ,     EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0     37616      113         -1    gamma        1.46917                0
# 1     52570      110         -1    gamma        3.65596                0
# 2    123276      128         -1    gamma        3.65596                0
# 3    224900      109         -1    gamma        3.65980                0
# 4    281751      121         -1    gamma        3.65980                0
# 5    349423      108         -1    gamma        3.98140                0
# 6    375323      105         -1    gamma        5.85867                0
# 7    387001      109         -1    gamma        3.65980                0
# 8    409759      119         -1    gamma        3.65596                0
# 9    410748      123         -1    gamma        5.85870                0
# 10   473311      109         -1    gamma        3.65980                0
#
#     XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0     3.68568    7.80000  -0.359938   2.158150  detectLogical_PV
# 1     5.04066    7.80000  -2.098100   9.037210  detectLogical_PV
# 2     9.79186    7.80000   0.140328   0.139416  detectLogical_PV
# 3     7.60335    7.80000   2.284660   2.277840  detectLogical_PV
# 4     5.57347    7.80000  -3.222770   0.744426  detectLogical_PV
# 5     8.15814    7.80000   2.324470   1.852960  detectLogical_PV
# 6     9.94199    7.80000   2.114750   2.194420  detectLogical_PV
# 7     6.80014    7.80000   3.138100   2.934510  detectLogical_PV
# 8     8.92519    7.80000  -2.702940   2.615890  detectLogical_PV
# 9     8.81076    7.54136   3.376810   1.355930  detectLogical_PV
# 10    3.05196    7.80000  -1.242490   0.361620  detectLogical_PV
#
#       ParentVolume
# ...
# 662    6.47202     7.8000  -3.285340   9.416960  detectLogical_PV
# 663    5.74284     7.8000  -0.194327   8.143210  detectLogical_PV
# 664    6.48911     7.8000  -1.774290   0.455568  detectLogical_PV
#
#        ParentVolume
# 0    sourcePhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 660  sourcePhysical
# 661  sourcePhysical
# 662  sourcePhysical
# 663  sourcePhysical
# 664  sourcePhysical
#
# [665 rows x 12 columns],      EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0        883      103         -1       e-       160.6750     3.412190e-23
# 1       3141      103         -1       e-        72.8107     6.689160e-23
# 2       3163      296         -1       e-        22.0413     1.256840e-22
# 3       3212      103         -1       e-        43.5990     8.368790e-23
# 4       3479      237         -1       e-        95.5444     4.420420e-23
# ..       ...      ...        ...      ...            ...              ...
# 667   498226      103         -1       e-        81.8101     4.247840e-23
# 668   498262      195         -1       e-        73.6850     4.306710e-23
# 669   499818      103         -1       e-        48.4428     8.495220e-23
# 670   499861      106         -1       e-       467.3140     6.712560e-23
# 671   499906      164         -1       e-        63.8420     4.649830e-23
#
#      XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0      8.95436        7.8   0.892958  30.007200  detectLogical_PV
# 1      8.52743        7.8   3.528570   8.944430  detectLogical_PV
# 2      9.40984        7.8   1.346010   6.979580  detectLogical_PV
# 3      4.72606        7.8  -0.735114  15.431300  detectLogical_PV
# 4      6.99347        7.8  -2.938860   1.424610  detectLogical_PV
# ..         ...        ...        ...        ...               ...
# 667    6.64939        7.8  -2.686670   0.574708  detectLogical_PV
# 668    9.76401        7.8  -0.777001   7.614050  detectLogical_PV
# 669    9.18605        7.8  -2.573140   2.717000  detectLogical_PV
# 670    9.22023        7.8  -1.153490   0.006852  detectLogical_PV
# 671    5.79038        7.8  -1.046550   2.545550  detectLogical_PV
#
#        ParentVolume
# 0    sourcePhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 667  sourcePhysical
# 668  sourcePhysical
# 669  sourcePhysical
# 670  sourcePhysical
# 671  sourcePhysical
#
# [672 rows x 12 columns],      EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0        248      211         -1       e-       157.5580     3.906210e-23
# 1       1083      279         -1       e-       141.9850     5.551800e-23
# 2       1873      133         -1       e-        72.3348     7.085510e-23
# 3       1989      161         -1       e-        94.4019     4.121380e-23
# 4       2765      114         -1       e-        21.1528     2.113670e-22
# ..       ...      ...        ...      ...            ...              ...
# 662   497714      103         -1       e-        37.1921     7.334610e-23
# 663   497881      103         -1       e-        43.1946     1.320290e-22
# 664   498173      103         -1       e-        69.8245     5.445800e-23
# 665   498352      103         -1       e-       155.0470     2.957480e-23
# 666   498441      106         -1       e-       172.1030     3.531460e-23
#
#      XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0      6.53356        7.8  -1.806700  10.431400  detectLogical_PV
# 1     10.23980        7.8  -1.071360   4.875110  detectLogical_PV
# 2      6.84045        7.8  -0.719893   3.541710  detectLogical_PV
# 3      6.77775        7.8  -0.474337   1.464250  detectLogical_PV
# 4      4.63925        7.8  -1.685030   0.620083  detectLogical_PV
# ..         ...        ...        ...        ...               ...
# 662    7.80603        7.8   0.331475   2.002610  detectLogical_PV
# 663    9.07217        7.8  -2.080500   5.551900  detectLogical_PV
# 664    5.58015        7.8   1.259270   5.937370  detectLogical_PV
# 665    5.42100        7.8   2.352620   4.841880  detectLogical_PV
# 666    6.37281        7.8   3.251730   6.181100  detectLogical_PV
#
#        ParentVolume
# 0    sourcePhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 662  sourcePhysical
# 663  sourcePhysical
# 664  sourcePhysical
# 665  sourcePhysical
# 666   worldPhysical
#
# [667 rows x 12 columns],      EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0        121      103         -1       e-       184.5180     2.494440e-23
# 1        683      103         -1       e-        57.0251     5.606390e-23
# 2       1339      103         -1       e-        16.9950     2.309320e-22
# 3       2914      124         -1       e-        64.4018     4.736690e-23
# 4       3283      267         -1       e-       149.7570     3.215000e-23
# ..       ...      ...        ...      ...            ...              ...
# 681   493367      300         -1       e-       181.3650     3.183900e-23
# 682   493882      103         -1       e-       112.5340     3.737910e-23
# 683   494057      166         -1       e-        65.8779     5.185350e-23
# 684   494521      103         -1       e-       146.9320     4.134090e-23
# 685   499877      225         -1       e-        21.3031     1.208190e-22
#
#      XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0      4.94041        7.8   1.243320    6.37765  detectLogical_PV
# 1      5.40907        7.8   0.365398    1.15398  detectLogical_PV
# 2      7.03767        7.8  -0.074547    1.66955  detectLogical_PV
# 3      6.48407        7.8   0.731315   10.13320  detectLogical_PV
# 4      7.97499        7.8   2.078900    2.40537  detectLogical_PV
# ..         ...        ...        ...        ...               ...
# 681    8.06611        7.8  -0.538531    3.83432  detectLogical_PV
# 682    9.75984        7.8   2.237290    1.65987  detectLogical_PV
# 683    8.24846        7.8   2.665960   10.36830  detectLogical_PV
# 684    5.03105        7.8   2.295160    3.36099  detectLogical_PV
# 685    6.75069        7.8   0.852506   10.28550  detectLogical_PV
#
#        ParentVolume
# 0    sourcePhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 681  sourcePhysical
# 682  sourcePhysical
# 683  sourcePhysical
# 684  sourcePhysical
# 685  sourcePhysical
#
# [686 rows x 12 columns],      EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0        153      184         -1       e-       64.59130     5.189500e-23
# 1        711      103         -1       e-       69.38250     5.868820e-23
# 2       2135      103         -1       e-        5.77518     3.844350e-22
# 3       2333      103         -1       e-      117.68500     3.266270e-23
# 4       3028      234         -1       e-      139.74000     2.903770e-23
# ..       ...      ...        ...      ...            ...              ...
# 686   494693      143         -1       e-      100.56300     6.978180e-23
# 687   495802      103         -1       e-       39.85780     8.349690e-23
# 688   498146      103         -1       e-      117.69200     4.078280e-23
# 689   498310      144         -1       e-       59.63480     5.256060e-23
# 690   499137      103         -1       e-       99.69120     3.685480e-23
#
#      XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0      6.39544        7.8   0.393134  14.448800  detectLogical_PV
# 1      5.92928        7.8  -0.289078  10.089800  detectLogical_PV
# 2      5.92959        7.8   0.838303   0.898712  detectLogical_PV
# 3      6.97836        7.8  -2.228630   1.842680  detectLogical_PV
# 4      4.72849        7.8  -0.526671   1.205160  detectLogical_PV
# ..         ...        ...        ...        ...               ...
# 686    8.79506        7.8  -0.193820   0.379623  detectLogical_PV
# 687    5.54552        7.8  -3.016960   7.108590  detectLogical_PV
# 688    9.21950        7.8   1.430370   2.764240  detectLogical_PV
# 689    5.57732        7.8   0.260215  31.250400  detectLogical_PV
# 690    7.81283        7.8  -3.479820   5.608900  detectLogical_PV
#
#        ParentVolume
# 0       subPhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 686  sourcePhysical
# 687  sourcePhysical
# 688  sourcePhysical
# 689  sourcePhysical
# 690  sourcePhysical
#
# [691 rows x 12 columns],      EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0        151      103         -1       e-        55.5319     5.941270e-23
# 1        600      103         -1       e-       196.1050     2.719840e-23
# 2        998      304         -1    gamma        44.0892     0.000000e+00
# 3       1150      103         -1       e-        70.2999     4.945170e-23
# 4       1271      103         -1       e-        61.6846     5.483990e-23
# ..       ...      ...        ...      ...            ...              ...
# 699   498165      209         -1       e-        49.7636     6.281040e-23
# 700   498782      103         -1       e-        56.1070     7.795190e-23
# 701   499754      115         -1       e-        33.1393     9.607860e-23
# 702   499912      103         -1       e-        32.2732     8.503990e-23
# 703   499957      126         -1       e-        41.3264     9.661200e-23
#
#      XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0      4.28698        7.8   0.797000    4.88336  detectLogical_PV
# 1      4.68996        7.8  -3.035820    1.36877  detectLogical_PV
# 2      5.71074        7.8   1.031870    3.69837  detectLogical_PV
# 3      6.34388        7.8  -0.873660    6.39673  detectLogical_PV
# 4      5.38407        7.8  -1.094560    5.79874  detectLogical_PV
# ..         ...        ...        ...        ...               ...
# 699    8.71049        7.8  -2.283610   12.54510  detectLogical_PV
# 700    6.50105        7.8  -0.304454   27.38670  detectLogical_PV
# 701    8.16971        7.8  -1.823220   18.67570  detectLogical_PV
# 702    7.57045        7.8  -1.238260    3.57668  detectLogical_PV
# 703    5.71473        7.8  -3.202490    2.17794  detectLogical_PV
#
#        ParentVolume
# 0    sourcePhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 699  sourcePhysical
# 700  sourcePhysical
# 701  sourcePhysical
# 702  sourcePhysical
# 703  sourcePhysical
#
# [704 rows x 12 columns],      EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0        882      103         -1       e-        87.6164     4.044400e-23
# 1       2023      124         -1       e-         2.4948     1.550590e-21
# 2       2177      103         -1       e-        58.0865     7.166470e-23
# 3       2227      103         -1       e-        46.6821     7.301570e-23
# 4       2325      103         -1       e-        80.7839     5.119000e-23
# ..       ...      ...        ...      ...            ...              ...
# 682   497439      106         -1       e-        89.5759     3.931080e-23
# 683   497493      103         -1       e-        14.0294     1.796430e-22
# 684   497693      183         -1       e-        72.1162     1.184660e-22
# 685   499887      103         -1       e-        89.3575     6.038240e-23
# 686   499926      103         -1       e-        44.2029     1.077850e-22
#
#      XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0      7.06384        7.8   1.796940   4.578610  detectLogical_PV
# 1      6.41619        7.3  -0.024032   0.409572  detectLogical_PV
# 2      9.73386        7.8   0.144515   4.717280  detectLogical_PV
# 3      6.30655        7.8   2.588990  34.404600  detectLogical_PV
# 4      8.17096        7.8  -0.869279   2.755550  detectLogical_PV
# ..         ...        ...        ...        ...               ...
# 682    4.89157        7.8  -2.378330   6.692310  detectLogical_PV
# 683    4.09532        7.8   1.700810   3.760270  detectLogical_PV
# 684    8.38296        7.8  -2.545400   7.937230  detectLogical_PV
# 685    9.78361        7.8   0.466051   5.758940  detectLogical_PV
# 686    7.79110        7.8   1.303200  10.830400  detectLogical_PV
#
#        ParentVolume
# 0    sourcePhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 682  sourcePhysical
# 683  sourcePhysical
# 684  sourcePhysical
# 685  sourcePhysical
# 686  sourcePhysical
#
# [687 rows x 12 columns],      EventID  TrackID  MigrantID Particle  InitialEnergy  DepositedEnergy  \
# 0       1596      103         -1       e-        20.1081     1.329350e-22
# 1       1746      103         -1       e-       173.0170     3.000060e-23
# 2       2092      134         -1       e-       103.9550     5.942920e-23
# 3       2662      103         -1       e-        52.9656     5.489630e-23
# 4       2767      174         -1       e-       143.6620     3.817040e-23
# ..       ...      ...        ...      ...            ...              ...
# 653   494153      172         -1    gamma         3.6598     0.000000e+00
# 654   496528      103         -1       e-        15.3668     1.823910e-22
# 655   497121      289         -1       e-        79.8686     4.096490e-23
# 656   498451      103         -1       e-        64.3454     5.216590e-23
# 657   499658      136         -1       e-        61.2873     5.398950e-23
#
#      XPosition  YPosition  ZPosition  LocalTime            Volume  \
# 0      7.37232        7.8   2.725470   4.544000  detectLogical_PV
# 1      6.25584        7.8   3.331940   4.439010  detectLogical_PV
# 2      8.74309        7.8  -1.635050  12.294700  detectLogical_PV
# 3      9.45034        7.8   0.986875   7.458940  detectLogical_PV
# 4      8.05206        7.8   2.755790   4.815730  detectLogical_PV
# ..         ...        ...        ...        ...               ...
# 653    9.55041        7.8   1.009620   3.925220  detectLogical_PV
# 654    7.47679        7.8  -1.514000   4.922600  detectLogical_PV
# 655    5.79375        7.8   0.698970   0.054523  detectLogical_PV
# 656    8.92570        7.8   1.065480   8.872100  detectLogical_PV
# 657    6.18316        7.8  -2.210760  18.359200  detectLogical_PV
#
#        ParentVolume
# 0    sourcePhysical
# 1    sourcePhysical
# 2    sourcePhysical
# 3    sourcePhysical
# 4    sourcePhysical
# ..              ...
# 653             NaN
# 654  sourcePhysical
# 655  sourcePhysical
# 656  sourcePhysical
# 657  sourcePhysical
#
# [658 rows x 12 columns]]
# getEnergy:   0%|          | 0/1000 [00:00<?, ?it/s]
# smearEnergy:   0%|          | 0/1000 [00:00<?, ?it/s]
# loadFile:   0%|          | 0/1000 [00:00<?, ?it/s]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# getEnergy:   0%|          | 0/1000 [00:00<?, ?it/s]
# smearEnergy:   0%|          | 0/1000 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print("The unique particles are:")
for run in particleEnergyList:
    print(f'{run}:',[[particle, len(particleEnergyList[run][particle])] for particle in particleEnergyList[run]])
# Out:
# The unique particles are:
# run0: [['gamma', 25675], ['e-', 43], ['neutron', 19]]
# run1: [['gamma', 7006], ['e-', 173]]
# run2: [['gamma', 542741], ['e-', 3549]]
# run3: [['e-', 653549], ['gamma', 18809]]
# run4: [['gamma', 23923], ['e-', 33]]
